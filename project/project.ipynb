# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,LabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
scalar = StandardScaler()
encoder = LabelBinarizer(neg_label=-1, pos_label=1, sparse_output=False)
response = data['diagnosis']
y = encoder.fit_transform(response)
feature = data.drop(['id', 'diagnosis'], axis=1)
X = scalar.fit_transform(feature)
norm_data = pd.concat([pd.DataFrame(X, columns = feature.columns.values), 
                       pd.DataFrame(y, columns = ['diagnosis'])],
                       axis = 1)

norm_data.head(25)
# Out:
#     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0      1.097064     -2.073335        1.269934   0.984375         1.568466
# 1      1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2      1.579888      0.456187        1.566503   1.558884         0.942210
# 3     -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4      1.750297     -1.151816        1.776573   1.826229         0.280372
# 5     -0.476375     -0.835335       -0.387148  -0.505650         2.237421
# 6      1.170908      0.160649        1.138125   1.095295        -0.123136
# 7     -0.118517      0.358450       -0.072867  -0.218965         1.604049
# 8     -0.320167      0.588830       -0.184080  -0.384207         2.201839
# 9     -0.473535      1.105439       -0.329482  -0.509063         1.582699
# 10     0.537556      0.919273        0.442011   0.406453        -1.017686
# 11     0.469393     -0.325708        0.479082   0.358672         0.052642
# ...

# %%
norm_data.corr()['diagnosis']
norm_data = norm_data.drop(['fractal_dimension_mean','texture_se','smoothness_se','symmetry_se'],axis=1)

# %%
#norm_data.corr()['diagnosis']
print(norm_data)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# 5      -0.476375     -0.835335       -0.387148  -0.505650         2.237421
# 6       1.170908      0.160649        1.138125   1.095295        -0.123136
# 7      -0.118517      0.358450       -0.072867  -0.218965         1.604049
# 8      -0.320167      0.588830       -0.184080  -0.384207         2.201839
# 9      -0.473535      1.105439       -0.329482  -0.509063         1.582699
# 10      0.537556      0.919273        0.442011   0.406453        -1.017686
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)
lr = LogisticRegression()
lr = lr.fit(X_train,y_train.ravel())
lr.score(X_test,y_test)
# Out:
# 0.98245614035087714

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.02, random_state=23)

# %%
print(pd.DataFrame(X_test,y_test))
# Out:
#           0         1         2         3         4         5         6   \
# -1 -0.533178 -0.314072 -0.564266 -0.553431 -0.698865 -0.711647 -0.627112
# -1  0.097334  1.326510  0.158210  0.004297 -0.568632  0.353616  0.151924
#  1  2.602339  1.717457  2.756900  2.929741  1.262455  1.972072  3.308243
# -1 -0.527497 -0.318726 -0.558499 -0.536936 -0.676803 -0.740642 -0.711733
#  1 -0.411051  1.058897 -0.382205 -0.443365  1.127241  0.414261  0.301328
#  1  1.577048  0.556251  1.562384  1.533287  0.114556  0.560187  1.224118
#  1  1.511725  0.009390  1.422337  1.462184  0.508101  0.274020  0.616458
# -1  0.210940  0.214172  0.170979  0.073978 -0.034891 -0.395915 -0.258122
# -1 -0.746188 -0.195392 -0.769805 -0.703884 -0.207111 -0.842033 -0.783673
#  1  1.383918 -0.088347  1.294648  1.374017 -1.009858 -0.455991  0.049099
#  1  3.775318  1.624375  3.910226  5.250529  0.856812  1.790138  3.448859
# -1 -1.570681 -0.160486 -1.560245 -1.233456  0.785646 -0.869323 -1.114873
#
# ...
